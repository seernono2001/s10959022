# %% [markdown]
# <a href="https://colab.research.google.com/github/seernono2001/s10959022/blob/master/assessment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("showtext")
install.packages("readr")
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘108_graduate.csv’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
staffdata <- read.csv("108_staff.csv")

# %%
library(showtext)
library(readr)
library(ggplot2)

# %%
str(staffdata)
# Out:
# 'data.frame':	152 obs. of  38 variables:
#  $ 學校代碼          : int  1 2 3 4 5 6 7 8 9 12 ...
#  $ 學校名稱          : chr  "國立政治大學" "國立清華大學" "國立臺灣大學" "國立臺灣師範大學" ...
#  $ 職員男            : int  169 187 484 193 135 155 135 107 114 101 ...
#  $ 職員女            : int  478 542 1115 568 349 431 394 329 292 174 ...
#  $ 秘書男            : int  0 1 2 5 5 5 1 3 7 2 ...
#  $ 秘書女            : int  8 22 42 29 20 19 17 27 21 9 ...
#  $ 教務男            : int  2 1 20 6 6 6 6 5 5 7 ...
#  $ 教務女            : int  8 40 63 43 25 37 23 22 25 17 ...
#  $ 學務男            : int  5 25 42 21 6 18 32 16 11 13 ...
#  $ 學務女            : int  11 56 70 52 12 40 35 34 15 20 ...
#  $ 總務男            : int  15 35 69 38 25 22 28 14 19 15 ...
#  $ 總務女            : int  11 55 86 67 13 21 42 44 24 21 ...
#  $ 會計男            : int  1 0 5 9 2 6 1 4 0 2 ...
#  $ 會計女            : int  11 28 58 24 27 24 20 19 19 10 ...
#  $ 人事男            : int  0 0 4 4 3 5 1 2 3 3 ...
#  $ 人事女            : int  12 27 31 21 26 18 15 11 10 8 ...
# ...

# %%
qplot(總務男,總務女,data=staffdata,geom=c("point","smooth"))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
qplot(環境安全男,data=staffdata,fill=環境安全女)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
qplot(工友女,工友男,data=staffdata)
# Out:
# plot without title

# %%
ggplot(staffdata,aes(x=職員男))+geom_bar()
# Out:
# plot without title

# %%
ggplot(staffdata,aes(x=警衛男,y=警衛女))+geom_point()
# Out:
# plot without title

# %%
ggplot(staffdata,aes(x=國際交流男,y=國際交流女))+geom_polygon()
# Out:
# plot without title
